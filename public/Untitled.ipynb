# %%
import os

print("Workspace content:", os.listdir("/workspace"))
print("Public content:", os.listdir("/workspace/public"))
# Out:
# Workspace content: ['agrisphere-ai-93aee827']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       3 print("Workspace content:", os.listdir("/workspace"))
# ----> 4 print("Public content:", os.listdir("/workspace/public"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/public'
